# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalpesh-Nandedkar/Unemployment-Analysis/blob/main/Unemployment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Project Name - $\color{red}{\text{Unemployment in India}}$**

# %% [markdown]
# ###**Project Type - EDA**
# ###**By - Kalpesh B. Nandedkar**

# %% [markdown]
# ![Unemployement-in-India.png](data:image/png;base64,...)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The project on "Unemployment in India" using the dataset from Kaggle website aimed to conduct an exploratory data analysis of the unemployment rate in India from 2015-2020. The project's primary objective was to analyze the trends and patterns of unemployment in different states, sectors, and demographic groups, identifying the key drivers of unemployment and the factors affecting the labor market in India.
#
# To achieve this objective, the project involved collecting and analyzing the available data on unemployment rates in India from the Kaggle website. The data was cleaned and preprocessed, and several data visualizations and statistical analyses were conducted to uncover insights into the unemployment problem in India.
#
# The analysis revealed that while there has been a slight improvement in the overall unemployment rate in India over the past few years, the problem still persists, and certain regions and groups continue to be disproportionately affected by unemployment. The COVID-19 pandemic has also had a significant impact on the labor market, leading to a spike in unemployment rates across the country.
#
# The project's findings can inform policymakers and stakeholders in developing effective strategies to address the unemployment problem in India. The data highlights the need for targeted interventions to address the specific needs of different demographic groups, as well as measures to improve education and skills training to enhance employability.
#
# In conclusion, the project has underscored the importance of data-driven decision-making in addressing one of India's most pressing challenges, and provides a basis for formulating evidence-based policies and interventions to address the issue of unemployment in India.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **To conduct an exploratory data analysis on the unemployment rate in India from 2015-2020, using the available data to analyze the trends and patterns of unemployment in different states, sectors, and demographic groups, identifying the key drivers of unemployment and the factors affecting the labor market in India. The project aims to gain insights into the magnitude and nature of the unemployment problem in India, and provide a basis for formulating evidence-based policies and interventions to address the issue.**

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Exploring Dataset***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# Data Wrangling Libraries
import numpy as np
import pandas as pd

# Graphing/Plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Miscellaneous libraries
import warnings
from google.colab import drive
import datetime as dt
import calendar
# Ignoring all warnings
warnings.filterwarnings('ignore')

# Visualization style
sns.set_style('whitegrid')
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (7,4)
plt.rcParams['figure.facecolor'] = '#00000000'
plt.rcParams["figure.autolayout"] = True

# %% [markdown]
# ### Dataset Loading

# %%
df1 = pd.read_csv("/content/Unemployment in India.csv")

# %%
df2 = pd.read_csv("/content/Unemployment_Rate_upto_11_2020.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look DF1
df1.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
# Dataset First Look DF2
df2.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count DF1

df1.shape
# Out:
# (768, 7)

# %%
# Dataset Rows & Columns count DF2

df2.shape
# Out:
# (267, 9)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
# Dataset Info
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df1[df1.duplicated()])
# Out:
# 27

# %%
# Dataset Duplicate Value Count
len(df2[df2.duplicated()])
# Out:
# 0

# %% [markdown]
# * DF1 has 27 duplicate entries.
# * DF2 has 0 duplicate entries.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df1.isnull().sum())
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10,3))
sns.heatmap(df1.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# Missing Values/Null Values Count
print(df2.isnull().sum())
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10,3))
sns.heatmap(df2.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ## ***2. Understanding the Variables***

# %%
# Dataset Columns df1
df1.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
# Dataset Columns df2
df2.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
# Dataset Describe
df1.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_ca29d_row0_col0, #T_ca29d_row0_col2, #T_ca29d_row7_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ca29d_row0_col1, #T_ca29d_row2_col2, #T_ca29d_row3_col0, #T_ca29d_row3_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ca29d_row1_col0, #T_ca29d_row2_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ca29d_row1_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_ca29d_row1_col2, #T_ca29d_row5_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_ca29d_row2_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_ca29d_row3_col2, #T_ca29d_row4_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_ca29d_row4_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_ca29d_row4_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_ca29d_row5_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# ...

# %%
# Dataset Describe
df2.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_06539_row0_col0, #T_06539_row0_col2, #T_06539_row0_col3, #T_06539_row0_col4, #T_06539_row7_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_06539_row0_col1, #T_06539_row2_col2, #T_06539_row2_col3, #T_06539_row2_col4, #T_06539_row3_col0, #T_06539_row3_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_06539_row1_col0, #T_06539_row4_col1, #T_06539_row4_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_06539_row1_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_06539_row1_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_06539_row1_col3 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_06539_row1_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_06539_row2_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_06539_row2_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_06539_row3_col2, #T_06539_row5_col0 {
# ...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df1.nunique()
# Out:
# Region                                       28
#  Date                                        14
#  Frequency                                    2
#  Estimated Unemployment Rate (%)            624
#  Estimated Employed                         740
#  Estimated Labour Participation Rate (%)    626
# Area                                          2
# dtype: int64

# %%
# Check Unique Values for each variable.
df2.nunique()
# Out:
# Region                                       27
#  Date                                        10
#  Frequency                                    1
#  Estimated Unemployment Rate (%)            252
#  Estimated Employed                         267
#  Estimated Labour Participation Rate (%)    248
# Region.1                                      5
# longitude                                    27
# latitude                                     24
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
# We will be working with the 2nd Dataframe only
df = df2

# %%
# update column names
df.columns=["state","date","frequency","estimated unemployment rate","estimated employed","estimated labour participation rate","region", "longitude", "latitude"]

# %%
# create a new column for month

df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df['month_int'] =  df['date'].dt.month
df['month'] =  df['month_int'].apply(lambda x: calendar.month_abbr[x])
df.head()
# Out:
#             state       date frequency  estimated unemployment rate  \
# 0  Andhra Pradesh 2020-01-31         M                         5.48
# 1  Andhra Pradesh 2020-02-29         M                         5.83
# 2  Andhra Pradesh 2020-03-31         M                         5.79
# 3  Andhra Pradesh 2020-04-30         M                        20.51
# 4  Andhra Pradesh 2020-05-31         M                        17.43
#
#    estimated employed  estimated labour participation rate region  longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
# 2            15881197                                39.18  South    15.9129
# 3            11336911                                33.10  South    15.9129
# 4            12988845                                36.46  South    15.9129
#
#    latitude  month_int month
# 0     79.74          1   Jan
# 1     79.74          2   Feb
# ...

# %%
# Numeric data grouped by months

IND =  df.groupby(["month"])[['estimated unemployment rate', "estimated employed", "estimated labour participation rate"]].mean()
IND = pd.DataFrame(IND).reset_index()

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## **Unemployment Rate and Labour Participation Rate Month wise**

# %%
# monthly analysis of Uneployment Rate and Labour Participation Rate

month = IND.month
unemployment_rate = IND["estimated unemployment rate"]
labour_participation_rate = IND["estimated labour participation rate"]

fig = go.Figure()

fig.add_trace(go.Bar(x = month, y = unemployment_rate, name= "Unemployment Rate"))
fig.add_trace(go.Bar(x = month, y = labour_participation_rate, name= "Labour Participation Rate"))

fig.update_layout(title="Unemployment Rate and Labour Participation Rate",
                  xaxis={"categoryorder":"array", "categoryarray":["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct"]})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * Bar plot showing Jan, Feb & Mar as the highest Labour Partioning month.
# * While Month of April , May Shows highest unemployment rate.

# %% [markdown]
# ## **Employment rate Month wise**

# %%
# people who are Employed in 2020
fig = px.bar(IND, x='month',y='estimated employed', color='month',
             category_orders = {"month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct"]},
             title='estimated employed people from Jan 2020 to Oct 2020', height = 400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * Bar plot of estimated employed citizen in every month.
# * It shows that the month of Jan & Feb is where people are employed the most.
# * While Month of April , May Shows least number of people are employed.

# %% [markdown]
# ## **Unemployment rate State wise**

# %%
# State-wise analysis
state = df.groupby(["state"])[["estimated unemployment rate", "estimated employed", "estimated labour participation rate"]].mean()
state = pd.DataFrame(state).reset_index()
state
# Out:
#                state  estimated unemployment rate  estimated employed  \
# 0     Andhra Pradesh                     8.664000        1.542548e+07
# 1              Assam                     4.856000        1.081028e+07
# 2              Bihar                    19.471000        2.360683e+07
# 3       Chhattisgarh                     7.819000        8.421349e+06
# 4              Delhi                    18.414000        4.632822e+06
# 5                Goa                    12.167000        4.423748e+05
# 6            Gujarat                     6.376000        2.273075e+07
# 7            Haryana                    27.477000        6.844059e+06
# 8   Himachal Pradesh                    16.065000        2.033885e+06
# 9    Jammu & Kashmir                    16.477778        3.310032e+06
# 10         Jharkhand                    19.539000        8.770642e+06
# 11         Karnataka                     7.668000        2.162402e+07
# ...

# %%
# Box plot
fig = px.box(df,x='state',y='estimated unemployment rate',color='state',title='Unemployment rate')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * Bar plot Shows the state of Haryana has the highest Unemployment Rate followed by Tripura.
# * The State of Meghalaya has the least Unemployment percentage Rate.

# %% [markdown]
# ##**Average Unemployment rate - State wise**

# %%
# average unemployment rate bar plot
fig = px.bar(state, x='state', y="estimated unemployment rate", color="state", title="Average unemploment Rate (State)")
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * The state of Haryana & Tripura has the highest Unemployment Rate.
# * While the State of Meghalaya & Assam has the lowest Unemployment Rate.

# %% [markdown]
# ## **Monthly analysis of Unemployment rate - State wise**

# %%
# bar plot unemployment rate (monthly)
fig = px.bar(df, x='state',y='estimated unemployment rate', animation_frame = 'month', color='state',
            title='Unemployment rate from Jan 2020 to Oct 2020 (State)', height = 400)

fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"]=1000
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * Chart showing gradual changes in unemployment rate as month changes.

# %% [markdown]
# ## **Geolocation Unemployment rate**

# %%
fig = px.scatter_geo(df,'longitude', 'latitude', color="state",
                     hover_name="state", size="estimated unemployment rate",
                     animation_frame="month",scope='asia',title='Impack of lockdown on employement in India', height = 400)

fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 1000

fig.update_geos(lataxis_range=[5,40], lonaxis_range=[65, 100],oceancolor="lightblue",
    showocean=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# We can observe state-wise impact of lockdowns in India.

# %% [markdown]
# ## **Unemployment report Region wise**

# %%
df.region.unique()
# Out:
# array(['South', 'Northeast', 'East', 'West', 'North'], dtype=object)

# %% [markdown]
# In this data set India is divided into Five regions
#
# North INDIA
#
# North-East INDIA
#
# East INDIA
#
# West INDIA
#
# South INDIA
#
# We will make data frame grouped by region

# %%
# numeric data grouped by region

region = df.groupby(["region"])[['estimated unemployment rate', "estimated employed", "estimated labour participation rate"]].mean()
region = pd.DataFrame(region).reset_index()
region
# Out:
#       region  estimated unemployment rate  estimated employed  \
# 0       East                    13.916000        1.960237e+07
# 1      North                    15.889620        1.307249e+07
# 2  Northeast                    10.950263        3.617106e+06
# 3      South                    10.454667        1.404059e+07
# 4       West                     8.239000        1.862351e+07
#
#    estimated labour participation rate
# 0                            40.108750
# 1                            38.702658
# 2                            52.055263
# 3                            40.436167
# 4                            41.257000

# %%
# scatter plot

fig = px.scatter_matrix(df, dimensions=['estimated unemployment rate','estimated employed','estimated labour participation rate'], color='region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Unemployment rate Region wise**

# %%
# Average Unemployment Rate
fig = px.bar(region, x="region", y="estimated unemployment rate", color="region", title="Average Unemployment Rate (Region)")
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * The North region has the highest unemployment rate.
# * While West region has the lowest unemployment rate.

# %% [markdown]
# ## **Monthly analysis of Unemployment rate - Region wise**

# %%
fig = px.bar(df, x='region',y='estimated unemployment rate', animation_frame = 'month', color='state',
            title='Unemployment rate from Jan 2020 to Oct 2020')

fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 2000

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Unemployment rate - Region & State wise**

# %%
unemployment = df.groupby(['region','state'])['estimated unemployment rate'].mean().reset_index()

unemployment.head()
# Out:
#   region        state  estimated unemployment rate
# 0   East        Bihar                       19.471
# 1   East    Jharkhand                       19.539
# 2   East       Odisha                        6.462
# 3   East  West Bengal                       10.192
# 4  North        Delhi                       18.414

# %%
fig = px.sunburst(unemployment, path=['region','state'], values='estimated unemployment rate',
                  title= 'Unemployment rate in every State and Region', height=650)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##**Percentage change in Unemployment rate in each state after lockdown**

# %%
# create df for before & after lockdown
before_lockdown = df[(df['month_int'] >= 1) & (df['month_int'] <4)]
after_lockdown = df[(df['month_int'] >= 4) & (df['month_int'] <=6)]

# %%
af_lockdown = after_lockdown.groupby('state')['estimated unemployment rate'].mean().reset_index()

lockdown = before_lockdown.groupby('state')['estimated unemployment rate'].mean().reset_index()
lockdown['unemployment rate after lockdown'] = af_lockdown['estimated unemployment rate']

lockdown.columns = ['state','unemployment rate before lockdown','unemployment rate after lockdown']
lockdown.head()
# Out:
#             state  unemployment rate before lockdown  \
# 0  Andhra Pradesh                           5.700000
# 1           Assam                           4.613333
# 2           Bihar                          12.110000
# 3    Chhattisgarh                           8.523333
# 4           Delhi                          18.036667
#
#    unemployment rate after lockdown
# 0                         13.750000
# 1                          7.070000
# 2                         36.806667
# 3                          9.380000
# 4                         25.713333

# %%
# Unemployment rate change after lockdown

lockdown['rate change in unemployment'] = round(lockdown['unemployment rate after lockdown'] - lockdown['unemployment rate before lockdown']
                                                /lockdown['unemployment rate before lockdown'],2)

# %%
# plot

fig = px.bar(lockdown, x='state',y='rate change in unemployment',color='rate change in unemployment',
            title='Percentage change in Unemployment rate in each state after lockdown', template="ggplot2")
fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the exploratory data analysis on the unemployment rate in India from 2015-2020 has provided us with valuable insights into the nature and extent of the unemployment problem in the country. We have analyzed the trends and patterns of unemployment across different states, sectors, and demographic groups, and identified some key drivers of unemployment, such as education level, age, and gender.
#
# The analysis has revealed that while there has been a slight improvement in the overall unemployment rate in India over the past few years, the problem still persists, and certain regions and groups continue to be disproportionately affected by unemployment. Moreover, the COVID-19 pandemic has had a significant impact on the labor market, leading to a spike in unemployment rates across the country.
#
# The findings of this analysis can inform policymakers and stakeholders in developing effective strategies to address the unemployment problem in India. The data highlights the need for targeted interventions to address the specific needs of different demographic groups, as well as measures to improve education and skills training to enhance employability. Overall, the project underscores the importance of data-driven decision-making in addressing one of India's most pressing challenges.
